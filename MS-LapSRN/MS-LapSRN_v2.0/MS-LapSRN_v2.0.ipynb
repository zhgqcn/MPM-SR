# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# 指定当前的工作文件夹
import os
# 此处为google drive中的文件路径,drive为之前指定的工作根目录，要加上
os.chdir("/content/drive/MyDrive/MS-LapSRN_v2.0/MS-LapSRN_v2.1")

# %%
# !python "train.py" --dataset "../../DataSet_test/" --nEpochs 10 --cuda --batchSize 1

# %%
# !python "train.py" --dataset "../../DataSet_less/" --nEpochs 100 --cuda --lr 0.001   # 没有权值初始化看看

# %%
import os
os.chdir("/content/drive/MyDrive/MS-LapSRN_v2.0/MS-LapSRN_v2.1")
# !python3 "test_single.py" --cuda --model "./result/LapSRN_model_epoch_r_400.pth" \
--input "/content/drive/My Drive/TestImg/val/95-512pix-speed7-ave1.tif" \
--outputHR2 "./result/MSLapSRN_v1.3_Epoch400_X2.tif" \
--outputHR4 "./result/MSLapSRN_v1.3_Epoch400_X4.tif"
# Out:
# Namespace(cuda=True, input='/content/drive/My Drive/TestImg/val/95-512pix-speed7-ave1.tif', model_r='./result/LapSRN_model_epoch_r_400.pth', outputHR2='./result/MSLapSRN_v1.3_Epoch400_X2.tif', outputHR4='./result/MSLapSRN_v1.3_Epoch400_X4.tif')
# Traceback (most recent call last):
#   File "test_single.py", line 66, in <module>
#     model_r, optimizer_r, epochs_r = load_model(model_r, optimizer_r, opt.model_r)
#   File "test_single.py", line 32, in load_model
#     model.load_state_dict(checkpoint['model'])
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py", line 1052, in load_state_dict
#     self.__class__.__name__, "\n\t".join(error_msgs)))
# RuntimeError: Error(s) in loading state_dict for LapSrnMS:
# ...

# %%
import os
os.chdir("/content/drive/MyDrive/MS-LapSRN/MS-LapSRN_v1.3/result/") 

# !python '/content/drive/MyDrive/MS-LapSRN/MS-LapSRN_v1.3/test.py' \
--input '/content/drive/My Drive/TestImg/val/95-512pix-speed7-ave1.tif' \
--model_r '/content/drive/MyDrive/MS-LapSRN/MS-LapSRN_v1.3/result/MSLapSRN_model_epoch_r_320.pth' \
--model_g '/content/drive/MyDrive/MS-LapSRN/MS-LapSRN_v1.3/result/MSLapSRN_model_epoch_g_300.pth' \
--outputHR2 'RGB_MS-LapSRN_v1.3_Epoch250_X2.tif' \
--outputHR4 'RGB_MS-LapSRN_v1.3_Epoch250_X4.tif'
# Out:
# Namespace(cuda=False, input='/content/drive/My Drive/TestImg/val/95-512pix-speed7-ave1.tif', model_g='/content/drive/MyDrive/MS-LapSRN/MS-LapSRN_v1.3/result/MSLapSRN_model_epoch_g_300.pth', model_r='/content/drive/MyDrive/MS-LapSRN/MS-LapSRN_v1.3/result/MSLapSRN_model_epoch_r_320.pth', outputHR2='RGB_MS-LapSRN_v1.3_Epoch250_X2.tif', outputHR4='RGB_MS-LapSRN_v1.3_Epoch250_X4.tif')
# output image saved to  RGB_MS-LapSRN_v1.3_Epoch250_X2.tif
# output image saved to  RGB_MS-LapSRN_v1.3_Epoch250_X4.tif
